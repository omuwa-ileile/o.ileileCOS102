# %%
#integer number
num = 100
print(num)
print("Data type of variable num is", type(num))

#float number
fnum = 34.45
print(num)
print("Data type of variable num is", type(num))

#integer number
num = 100
print(num)
print("Data type of variable num is", type(num))
