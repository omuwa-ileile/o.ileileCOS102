# %%
#Simple Interest Program
print("Solving for Amount on Simple Interest")
p = float(input("Enter Principal:"))
r = float(input("Enter Rate in %:"))
t = float(input("Enter Time in years:"))

a = p * (1 + (r / 100) * t)
print("Amount =",a)

#Compound Interest Program
print("Solving for Amount on Compound Interest")
p = float(input("Enter Principal:"))
r = float(input("Enter Rate in %:"))
t = float(input("Enter Time in years:"))
n = float(input("Enter number of times interest is compounded per year:"))

a = p * (1 + (r / 100) / n) **(n * t)
print("Amount =",a)

#Annuity Plan Program
print("Solving for Amount on Annuity Plan")
pmt = float(input("Enter payment per period:"))
r = float(input("Enter Rate in %:"))
t = float(input("Enter Time in years:"))
n = float(input("Enter number of payments per year:"))

a = pmt * (((1 + (r / 100) / n) ** (n * t) - 1) / ((r / 100) / n))
print("Annuity =",a)
# Out:
# Solving for Amount on Simple Interest
# Enter Principal: 1
# Enter Rate in %: 1
# Enter Time in years: 1
# Amount = 1.01
# Solving for Amount on Compound Interest
# Enter Principal: 1
# Enter Rate in %: 1
# Enter Time in years: 1
# Enter number of times interest is compounded per year: 1
# Amount = 1.01
# Solving for Amount on Annuity Plan
# Enter payment per period: 1
# Enter Rate in %: 1
# Enter Time in years: 1
# Enter number of payments per year: 1
# Annuity = 1.0000000000000009

# %% [markdown]
# ![](Slide2.png)

# %% [markdown]
# ![](Slide3.png)

# %% [markdown]
# ![](Slide4.png)
