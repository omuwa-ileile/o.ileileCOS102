# %% [markdown]
# START
# INPUT NAME1
# SET INPUT1 TO NAME1
# INPUT AGE1
# SET INPUT2 TO AGE1
# INPUT NAME2
# SET INPUT3 TO NAME2
# INPUT AGE2
# SET INPUT4 TO AGE2
# CREATE TEMPORARY VARIABLE AGE
# SET AGE TO AGE1
# SET AGE1 TO AGE2
# SET AGE2 TO AGE
# PRINT NAME1 IS AGE1 YEARS OLD
# PRINT NAME2 IS AGE2 YEARS OLD
