# %%
print("IZFIN TECHNOLOGY ANNUAL TAX REVENUE GENERATOR")
age = float(input("Enter your age:"))
yox = float(input("Enter your years of experience:"))

if yox > 25 and age >= 55:
    print("Your annual tax revenue is 5,600,000")
elif yox > 20 and age >= 45:
    print("Your annual tax revenue is 4,480,000")
elif yox > 10 and age >= 35:
    print("Your annual tax revenue is 1,500,000")
else:
    print("Your annual tax revenue is 550,000")
# Out:
# IZFIN TECHNOLOGY ANNUAL TAX REVENUE GENERATOR
# Enter your age: 50
# Enter your years of experience: 22
# Your annual tax revenue is 4,480,000
